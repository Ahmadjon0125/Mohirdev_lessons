# %%
import pandas as pd

# %%
df = pd.read_csv('merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
pd.read_excel('uzbekistan.xlsx')
# Out:
#                        Boʻlinishi  Maydoni (kv.km)  Aholisi
# 0                Andijon viloyati             4200  1899000
# 1                 Buxoro viloyati            39400  1384700
# 2               Fargʻona viloyati             6800  2597000
# 3                 Jizzax viloyati            20500   910500
# 4                 Xorazm viloyati             6300  1200000
# 5               Namangan viloyati             7900  1862000
# 6                 Navoiy viloyati           110800   767500
# 7            Qashqadaryo viloyati            28400  2029000
# 8   Qoraqalpogʻiston Respublikasi           160000  1200000
# 9              Samarqand viloyati            16400  2322000
# 10              Sirdaryo viloyati             5100   648100
# 11           Surxondaryo viloyati            20800  1676000
# 12              Toshkent viloyati            15300  4450000

# %%
pd.read_excel('uzbekistan.xlsx', index_col=0)
# Out:
#                                Maydoni (kv.km)  Aholisi
# Boʻlinishi
# Andijon viloyati                          4200  1899000
# Buxoro viloyati                          39400  1384700
# Fargʻona viloyati                         6800  2597000
# Jizzax viloyati                          20500   910500
# Xorazm viloyati                           6300  1200000
# Namangan viloyati                         7900  1862000
# Navoiy viloyati                         110800   767500
# Qashqadaryo viloyati                     28400  2029000
# Qoraqalpogʻiston Respublikasi           160000  1200000
# Samarqand viloyati                       16400  2322000
# Sirdaryo viloyati                         5100   648100
# Surxondaryo viloyati                     20800  1676000
# Toshkent viloyati                        15300  4450000

# %%
pd.read_excel('uzbekistan.xlsx', index_col=0 , names=['hudud', 'maydon', 'aholi'])
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv('automobile_data.csv',sep=',',index_col='index', nrows=15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df = pd.read_excel('uzbekistan.xlsx', index_col=0 , names=['hudud', 'maydon', 'aholi'])
df
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
df.to_csv('new_uzb.csv')

# %%
obj = df.maydon
obj
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
obj.to_csv('objmaydon.csv')

# %%
pd.read_csv('objmaydon.csv')
# Out:
#                             hudud  maydon
# 0                Andijon viloyati    4200
# 1                 Buxoro viloyati   39400
# 2               Fargʻona viloyati    6800
# 3                 Jizzax viloyati   20500
# 4                 Xorazm viloyati    6300
# 5               Namangan viloyati    7900
# 6                 Navoiy viloyati  110800
# 7            Qashqadaryo viloyati   28400
# 8   Qoraqalpogʻiston Respublikasi  160000
# 9              Samarqand viloyati   16400
# 10              Sirdaryo viloyati    5100
# 11           Surxondaryo viloyati   20800
# 12              Toshkent viloyati   15300

# %%
pd.read_csv('objmaydon.csv', index_col='hudud').squeeze()
# Out:
# hudud
# Andijon viloyati                   4200
# Buxoro viloyati                   39400
# Fargʻona viloyati                  6800
# Jizzax viloyati                   20500
# Xorazm viloyati                    6300
# Namangan viloyati                  7900
# Navoiy viloyati                  110800
# Qashqadaryo viloyati              28400
# Qoraqalpogʻiston Respublikasi    160000
# Samarqand viloyati                16400
# Sirdaryo viloyati                  5100
# Surxondaryo viloyati              20800
# Toshkent viloyati                 15300
# Name: maydon, dtype: int64

# %%
df2  = pd.read_csv('automobile_data.csv', index_col=0)
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
df2.to_excel('newcars.xlsx', index=False, columns=['company', 'body-style', 'price'])

# %%
pd.read_excel('newcars.xlsx')
# Out:
#         company   body-style    price
# 0   alfa-romero  convertible  13495.0
# 1   alfa-romero  convertible  16500.0
# 2   alfa-romero    hatchback  16500.0
# 3          audi        sedan  13950.0
# 4          audi        sedan  17450.0
# ..          ...          ...      ...
# 56   volkswagen        sedan   7975.0
# 57   volkswagen        sedan   7995.0
# 58   volkswagen        sedan   9995.0
# 59        volvo        sedan  12940.0
# 60        volvo        wagon  13415.0
#
# [61 rows x 3 columns]

# %% [markdown]
# ### ```HDF5``` format

# %%
hdf5obj = pd.HDFStore('data.h5')

# %%
hdf5obj.put("uzdata", df)

# %%
hdf5obj.put('cardata', df2)

# %%
hdf5obj.keys()
# Out:
# ['/cardata', '/uzdata']

# %%
hdf5obj['uzdata']
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
hdf5obj.close() # yopish kerak ekan, yopilgan holatda ichidagilarni ham ko'ra olmas ekanmiz

# %%
hdf5obj= pd.HDFStore('data.h5') # qaytadan ochish uchun

# %%
hdf5obj['cardata']
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
hdf5obj.close()

# %%
data = pd.read_hdf('data.h5', key='uzdata')
data
# Out:
#                                maydon    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
data.to_hdf("data.h5", key='uzdata')

# %% [markdown]
# ### Web sahifalar

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# bazi websaytlar pandasdan yuborilgan so'rovlar uchun javob bermas ekan , bu agent niqob bo'lsa keyin berarkan

tashkent = pd.read_html('https://en.wikipedia.org/wiki/Tashkent', storage_options=headers)
tashkent[6]
# Out:
#                                                     0  \
# 0                               Historical population
# 1   YearPop.±% p.a.1897 155,673— 1959 911,930+2.89...
# 2                                                Year
# 3                                                1897
# 4                                                1959
# 5                                                1970
# 6                                                1979
# 7                                                1983
# 8                                                1989
# 9                                                1991
# 10                                               1995
# 11                                               2000
# 12                                               2001
# 13                                               2002
# 14                                               2003
# 15                                               2004
# ...

# %% [markdown]
# ### ```JSON```

# %%
df = pd.read_json('comments.json')
df
# Out:
#                                             comments
# 0  {'id': 1, 'post_id': 101, 'user_id': 5, 'autho...
# 1  {'id': 2, 'post_id': 101, 'user_id': 8, 'autho...
# 2  {'id': 3, 'post_id': 102, 'user_id': 3, 'autho...
# 3  {'id': 4, 'post_id': 101, 'user_id': 12, 'auth...
# 4  {'id': 5, 'post_id': 103, 'user_id': 7, 'autho...
# 5  {'id': 6, 'post_id': 102, 'user_id': 15, 'auth...
# 6  {'id': 7, 'post_id': 104, 'user_id': 2, 'autho...
# 7  {'id': 8, 'post_id': 103, 'user_id': 9, 'autho...
# 8  {'id': 9, 'post_id': 104, 'user_id': 11, 'auth...
# 9  {'id': 10, 'post_id': 105, 'user_id': 4, 'auth...

# %%
df_new = pd.DataFrame(df['comments'].tolist())
df_new.drop(['id'],axis=1)
# Out:
#    post_id  user_id         author  \
# 0      101        5    Alice Brown
# 1      101        8     Bob Wilson
# 2      102        3  Charlie Davis
# 3      101       12   Diana Miller
# 4      103        7     Edward Lee
# 5      102       15   Fiona Garcia
# 6      104        2     George Kim
# 7      103        9   Hannah White
# 8      104       11      Ivan Chen
# 9      105        4    Julia Adams
#
#                                              content               created  \
# 0  Great article! Very informative and well-written.  2024-01-10T14:30:00Z
# 1  I disagree with some points, but overall a goo...  2024-01-10T15:45:00Z
# 2           This helped me solve my problem. Thanks!  2024-01-11T09:15:00Z
# 3         Can you elaborate more on the third point?  2024-01-10T16:20:00Z
# 4                    First! Great content as always.  2024-01-12T08:00:00Z
# 5  I've been looking for this information everywh...  2024-01-11T11:30:00Z
# ...
