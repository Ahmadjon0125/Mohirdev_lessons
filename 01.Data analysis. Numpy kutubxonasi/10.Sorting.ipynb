# %%
import numpy as np

# %%
data = np.random.rand(4)
data
# Out:
# array([0.45817301, 0.17530234, 0.73072282, 0.88108276])

# %%
sorted_array = np.sort(data)
sorted_array
# Out:
# array([0.17530234, 0.45817301, 0.73072282, 0.88108276])

# %%
data.sort()
data
# Out:
# array([0.17530234, 0.45817301, 0.73072282, 0.88108276])

# %%
rev_arr = -np.sort(-data)
rev_arr
# Out:
# array([0.88108276, 0.73072282, 0.45817301, 0.17530234])

# %%
arr2d = np.random.randn(2,4)
arr2d
# Out:
# array([[ 1.42349812, -0.80085529, -0.1862582 ,  0.44305314],
#        [ 0.3935078 ,  0.00534931, -0.31397585,  0.16696637]])

# %%
#axis=0 --->Qator 
row_srt = np.sort(arr2d, axis = 0)
row_srt
# Out:
# array([[ 0.3935078 , -0.80085529, -0.31397585,  0.16696637],
#        [ 1.42349812,  0.00534931, -0.1862582 ,  0.44305314]])

# %%
#axis=1 --->Ustun
col_srt = np.sort(arr2d, axis=1)
col_srt
# Out:
# array([[-0.80085529, -0.1862582 ,  0.44305314,  1.42349812],
#        [-0.31397585,  0.00534931,  0.16696637,  0.3935078 ]])
