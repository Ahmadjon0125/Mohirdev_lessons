# %%
import numpy as np

# %%
arr1 = np.array([1,2,3], dtype=np.float64) 
arr1
# Out:
# array([1., 2., 3.])

# %%
arr2 = np.array([1,2,3], dtype=np.int32) 
arr2
# Out:
# array([1, 2, 3], dtype=int32)

# %%
arr1.dtype
# Out:
# dtype('float64')

# %% [markdown]
# dtype o'zgartirish (astype())

# %%
new_arr=arr1.astype(np.int16)
new_arr.dtype
# Out:
# dtype('int16')
