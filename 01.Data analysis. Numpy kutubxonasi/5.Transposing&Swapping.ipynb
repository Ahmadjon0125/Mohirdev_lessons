# %%
import numpy as np

# %%
A = np.arange(6).reshape(3,2)
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %% [markdown]
# Transpose

# %%
A.T # A massivning Transpose ko'rinishi
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %% [markdown]
# Swapaxes

# %%
A
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
A.swapaxes(1,0)
# Out:
# array([[0, 2, 4],
#        [1, 3, 5]])

# %% [markdown]
# dot()

# %%
np.dot(A, A.T)
# Out:
# array([[ 1,  3,  5],
#        [ 3, 13, 23],
#        [ 5, 23, 41]])
