# %%
import numpy as np

# %% [markdown]
# Python va Numpy orasidagi farq

# %%
my_list = list(range(100000000000000))
my_array = np.array(range(100000000000000))

# %%
# %time for _ in range(10): [x*2 for x in my_list]
# Out:
# CPU times: user 692 μs, sys: 0 ns, total: 692 μs
# Wall time: 697 μs

# %%
# %time for _ in range(10): my_array*2
# Out:
# CPU times: user 84 μs, sys: 0 ns, total: 84 μs
# Wall time: 88 μs
