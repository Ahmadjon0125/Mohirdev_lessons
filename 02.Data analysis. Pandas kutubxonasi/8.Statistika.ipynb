# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/uzbekistan.csv', index_col=0)
df.columns = ['maydoni','aholisi']
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.sum()
# Out:
# maydoni      441900.0
# aholisi    22945800.0
# dtype: float64

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/gm_sales.csv", index_col=0)
df2.head()
# Out:
#          2020   2021
# Labo     4521   7542
# Damas   30889  33682
# Spark   16370   6485
# Nexia   41663  14442
# Cobalt  44901  36317

# %%
df2.sum()
# Out:
# 2020    168712
# 2021    124734
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# Labo      12063
# Damas     64571
# Spark     22855
# Nexia     56105
# Cobalt    81218
# Gentra    56634
# dtype: int64

# %%
df2.mean(axis=1)
# Out:
# Labo       6031.5
# Damas     32285.5
# Spark     11427.5
# Nexia     28052.5
# Cobalt    40609.0
# Gentra    28317.0
# dtype: float64

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df.mean()
# Out:
# maydoni    3.399231e+04
# aholisi    1.765062e+06
# dtype: float64

# %%
df.idxmax()
# Out:
# maydoni    Qoraqalpogʻiston Respublikasi
# aholisi                Toshkent viloyati
# dtype: str

# %%
df.idxmin()
# Out:
# maydoni     Andijon viloyati
# aholisi    Sirdaryo viloyati
# dtype: str

# %%
df
# Out:
#                                 maydoni    aholisi
# Boʻlinishi
# Andijon viloyati                 4200.0  1899000.0
# Buxoro viloyati                 39400.0  1384700.0
# Fargʻona viloyati                6800.0  2597000.0
# Jizzax viloyati                 20500.0   910500.0
# Xorazm viloyati                  6300.0  1200000.0
# Namangan viloyati                7900.0  1862000.0
# Navoiy viloyati                110800.0   767500.0
# Qashqadaryo viloyati            28400.0  2029000.0
# Qoraqalpogʻiston Respublikasi  160000.0  1200000.0
# Samarqand viloyati              16400.0  2322000.0
# Sirdaryo viloyati                5100.0   648100.0
# Surxondaryo viloyati            20800.0  1676000.0
# Toshkent viloyati               15300.0  4450000.0

# %%
df['aholisi'].argmax()
# Out:
# np.int64(12)

# %%
df.iloc[12]
# Out:
# maydoni      15300.0
# aholisi    4450000.0
# Name: Toshkent viloyati, dtype: float64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df.shape
# Out:
# (13119, 9)

# %%
df.tail()
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9

# %%
df.sample(10)
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 1567      E Class  2017  20400    Semi-Auto    25069   Diesel  145  72.4
# 1182      B Class  2017  13499       Manual    22926   Diesel   20  68.9
# 2339      E Class  2016  16480    Semi-Auto    21441   Diesel  125  61.4
# 5845      C Class  2017  17490    Automatic    37484   Diesel  145  64.2
# 12459     A Class  2017  13000       Manual    40082   Diesel   20  72.4
# 2836      C Class  2019  24980    Semi-Auto    11589   Petrol  145  45.6
# 9285      C Class  2019  30995    Automatic     5999   Petrol  145  42.8
# 11254     C Class  2016  16449    Automatic    27268   Diesel   30  64.2
# 11866   GLE Class  2017  29450    Automatic    30000   Diesel  145  42.8
# 7537      C Class  2019  26899    Semi-Auto     2000   Petrol  145  45.6
#
#        engineSize
# 1567          2.0
# 1182          1.5
# 2339          2.1
# 5845          2.1
# 12459         1.5
# 2836          1.5
# 9285          2.0
# 11254         2.1
# 11866         3.0
# 7537          1.5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  str
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  str
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  str
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), str(3)
# memory usage: 922.6 KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
df['year'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13119 entries, 0 to 13118
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  str
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  str
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  str
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), str(3)
# memory usage: 922.6 KB

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %%
data = {
    'age':[10,20,30,40,50,60],
    'year':[2010,2000,1990,1980,1970,1960],
}

obj = pd.DataFrame(data)
obj
# Out:
#    age  year
# 0   10  2010
# 1   20  2000
# 2   30  1990
# 3   40  1980
# 4   50  1970
# 5   60  1960

# %%
obj['age'].corr(obj['year'])
# Out:
# np.float64(-0.9999999999999998)

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %%
df['year'].corr(df['mileage'])
# Out:
# np.float64(-0.7380268515364226)

# %%
df.corr(numeric_only=True)
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
df.corrwith(df['price'], numeric_only=True)
# Out:
# year          0.520712
# price         1.000000
# mileage      -0.537214
# tax           0.268717
# mpg          -0.438445
# engineSize    0.516126
# dtype: float64

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %% [markdown]
# ### Filterlash
# ```unique()```

# %%
df['model'].unique()
# Out:
# <StringArray>
# [      ' SLK',   ' S Class',  ' SL CLASS',   ' G Class', ' GLE Class',
#  ' GLA Class',   ' A Class',   ' B Class', ' GLC Class',   ' C Class',
#    ' E Class',  ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#    ' V Class',   ' M Class',  ' CL Class', ' GLS Class', ' GLB Class',
#    ' X-CLASS',        '180',       ' CLK',   ' R Class',        '230',
#         '220',        '200']
# Length: 27, dtype: str

# %%
models = df['model'].unique()
models = np.sort(models)
models
# Out:
# array([' A Class', ' B Class', ' C Class', ' CL Class', ' CLA Class',
#        ' CLC Class', ' CLK', ' CLS Class', ' E Class', ' G Class',
#        ' GL Class', ' GLA Class', ' GLB Class', ' GLC Class',
#        ' GLE Class', ' GLS Class', ' M Class', ' R Class', ' S Class',
#        ' SL CLASS', ' SLK', ' V Class', ' X-CLASS', '180', '200', '220',
#        '230'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2005, 2017, 2016, 2011, 2018, 2012, 2019, 2020, 2014, 2015, 2006,
#        2010, 2004, 2008, 2013, 2007, 2009, 2003, 2001, 2002, 1998, 2000,
#        1997, 1999, 1970])

# %%
df['fuelType'].unique()
# Out:
# <StringArray>
# ['Petrol', 'Hybrid', 'Diesel', 'Other']
# Length: 4, dtype: str

# %%
df['model'].value_counts() ### har biridan nechtadan borligini hisoblaydi
# Out:
# model
#  C Class      3747
#  A Class      2561
#  E Class      1953
#  GLC Class     960
#  GLA Class     847
#  B Class       591
#  CL Class      511
#  GLE Class     461
#  SL CLASS      260
#  CLS Class     237
#  V Class       207
#  S Class       197
#  GL Class      121
#  SLK            95
#  CLA Class      86
#  X-CLASS        82
#  M Class        79
#  GLS Class      74
#  GLB Class      19
#  G Class        15
#  CLK             7
#  CLC Class       3
#  R Class         2
# 180              1
# 230              1
# 220              1
# 200              1
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Semi-Auto    6848
# Automatic    4825
# Manual       1444
# Other           2
# Name: count, dtype: int64

# %%
df['model'].unique()
# Out:
# <StringArray>
# [      ' SLK',   ' S Class',  ' SL CLASS',   ' G Class', ' GLE Class',
#  ' GLA Class',   ' A Class',   ' B Class', ' GLC Class',   ' C Class',
#    ' E Class',  ' GL Class', ' CLS Class', ' CLC Class', ' CLA Class',
#    ' V Class',   ' M Class',  ' CL Class', ' GLS Class', ' GLB Class',
#    ' X-CLASS',        '180',       ' CLK',   ' R Class',        '230',
#         '220',        '200']
# Length: 27, dtype: str

# %%
models = [' SLK', ' CLS Class']
filtr = df['model'].isin(models)
filtr
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114    False
# 13115    False
# 13116    False
# 13117     True
# 13118    False
# Name: model, Length: 13119, dtype: bool

# %%
df2 = df[filtr]
df2
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 26      CLS Class  2016  25077    Automatic    13887   Diesel  165  49.6
# 40            SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# 41      CLS Class  2018  34990    Automatic    18837   Diesel  150  47.9
# 52            SLK  2004   4890    Automatic    46000   Petrol  330  28.0
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13057   CLS Class  2016  17999    Automatic    47156   Diesel  125  57.7
# 13085   CLS Class  2016  22684    Automatic    32611   Diesel  165  49.6
# 13095   CLS Class  2016  20399    Automatic    16107   Diesel  160  51.4
# 13108         SLK  2016  17499    Automatic    30128   Diesel   30  70.6
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
#
#        engineSize
# 0             1.8
# 26            3.0
# 40            1.8
# 41            2.9
# 52            3.5
# ...           ...
# 13057         2.1
# 13085         3.0
# 13095         3.0
# 13108         2.1
# 13117         2.0
#
# [332 rows x 9 columns]

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %%
filtr2 = df['fuelType'].isin([ 'Hybrid'])
df3 = df[filtr2]
df3
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 1       S Class  2017  34948    Automatic    27000   Hybrid   20   61.4
# 77      S Class  2016  24880    Automatic    75000   Hybrid  190   42.4
# 137     C Class  2017  21000    Automatic    25000   Hybrid  140  134.5
# 327     E Class  2019  39998    Semi-Auto     2675   Hybrid  135  134.5
# 329     C Class  2016  18498    Semi-Auto    31891   Hybrid    0  134.5
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 12687   C Class  2017  17480    Automatic    47019   Hybrid    0  134.5
# 12707   S Class  2019  56890    Automatic     2931   Hybrid  135  100.9
# 12713   C Class  2017  20480    Automatic    30053   Hybrid    0  134.5
# 12867   S Class  2017  36890    Automatic    22657   Hybrid   20   61.4
# 12999   C Class  2016  15999    Automatic    66077   Hybrid    0  134.5
#
#        engineSize
# 1             2.1
# 77            3.5
# 137           2.0
# 327           2.0
# 329           2.0
# ...           ...
# 12687         2.0
# 12707         3.0
# 12713         2.0
# 12867         2.1
# 12999         2.0
#
# [173 rows x 9 columns]

# %%
df[df['year'] > 2019]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 10        A Class  2020  32980    Automatic      606   Petrol  145  35.8
# 11        A Class  2020  26980    Automatic     1000   Diesel  145  62.8
# 33        A Class  2020  28128    Automatic     2563   Petrol  145  47.9
# 38        C Class  2020  31790    Automatic     3500   Petrol  145  64.2
# 57      GLE Class  2020  48995    Automatic     3000   Diesel  145  36.7
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13053     A Class  2020  27995    Automatic     2500   Diesel  145  67.3
# 13056   GLE Class  2020  58450    Automatic     1159   Diesel  150  32.8
# 13113     C Class  2020  30999    Automatic     1000   Diesel  145  64.2
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 10            2.0
# 11            1.5
# 33            1.3
# 38            2.0
# 57            2.0
# ...           ...
# 13053         1.5
# 13056         2.9
# 13113         2.0
# 13114         2.0
# 13115         2.0
#
# [719 rows x 9 columns]

# %%
df[(df['year'] > 2019) & (df['price'] < 20000)]
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 1840   B Class  2020  19890       Manual     2001   Petrol  145  45.6
# 5934   A Class  2020  16862       Manual    29515   Petrol  150  47.1
#
#       engineSize
# 1840         1.3
# 5934         1.3

# %%
df[df.transmission == "Automatic"]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [4825 rows x 9 columns]

# %%
df[df.transmission != "Semi-Auto"]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [6271 rows x 9 columns]

# %%
df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %%
df.engineSize == 2.0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114     True
# 13115     True
# 13116    False
# 13117     True
# 13118    False
# Name: engineSize, Length: 13119, dtype: bool

# %%
df[df.engineSize == 2.0]
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 10        A Class  2020  32980    Automatic      606   Petrol  145  35.8
# 12        B Class  2019  23750    Automatic      278   Diesel  145  55.4
# 20        C Class  2019  26601    Automatic     9949   Diesel  150  64.2
# 28       SL CLASS  2018  22914    Automatic     8725   Petrol  145  47.9
# 30        C Class  2019  29546    Automatic     7990   Diesel  145  54.3
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13112     C Class  2019  30399    Automatic     5000   Diesel  145  61.4
# 13113     C Class  2020  30999    Automatic     1000   Diesel  145  64.2
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
#
#        engineSize
# 10            2.0
# 12            2.0
# 20            2.0
# 28            2.0
# 30            2.0
# ...           ...
# 13112         2.0
# 13113         2.0
# 13114         2.0
# 13115         2.0
# 13117         2.0
#
# [3739 rows x 9 columns]

# %%
import pandas as pd
ds = pd.read_csv("dataset.csv")
ds = ds[ds.COUNTRY == ds.iloc[18272].COUNTRY]

ds
# Out:
#                         DATASET  \
# 18272  IMF.STA:GFS_SSUC(10.0.0)
# 18913  IMF.STA:GFS_SSUC(10.0.0)
# 19113  IMF.STA:GFS_SSUC(10.0.0)
# 19190  IMF.STA:GFS_SSUC(10.0.0)
# 19276  IMF.STA:GFS_SSUC(10.0.0)
# ...                         ...
# 37434  IMF.STA:GFS_SSUC(10.0.0)
# 38901  IMF.STA:GFS_SSUC(10.0.0)
# 38903  IMF.STA:GFS_SSUC(10.0.0)
# 38960  IMF.STA:GFS_SSUC(10.0.0)
# 38996  IMF.STA:GFS_SSUC(10.0.0)
#
#                                          SERIES_CODE OBS_MEASURE  \
# 18272              UZB.S1321.TFAL.DC_L_TCB_CAB.XDC.A   OBS_VALUE
# 18913           UZB.S1321.BI.GNFB_TCB_CAB.POGDP_PT.A   OBS_VALUE
# 19113               UZB.S1321.G1.G1M13A_TCB_MI.XDC.A   OBS_VALUE
# 19190                UZB.S1311.G2M.G24_TCB_CAB.XDC.A   OBS_VALUE
# 19276            UZB.S1311.BI.GPB_TCB_CAB.POGDP_PT.A   OBS_VALUE
# ...                                              ...         ...
# 37434          UZB.S1314.G1.G1M13A_TCB_MI.POGDP_PT.A   OBS_VALUE
# 38901         UZB.S1311B.G1.G1M13A_TCB_MI.POGDP_PT.A   OBS_VALUE
# 38903            UZB.S1321.G1.G11_TCB_CAB.POGDP_PT.A   OBS_VALUE
# 38960      UZB.S1311B.TFAL.G32OTC_A_TCB_CAB_MI.XDC.A   OBS_VALUE
# 38996  UZB.S1312MIXED.TFAL.G32OTC_A_TCB_CAB_MI.XDC.A   OBS_VALUE
#
#                        COUNTRY                                        SECTOR  \
# 18272  Uzbekistan, Republic of  Central government including social security
# 18913  Uzbekistan, Republic of  Central government including social security
# 19113  Uzbekistan, Republic of  Central government including social security
# 19190  Uzbekistan, Republic of  Central government excluding social security
# 19276  Uzbekistan, Republic of  Central government excluding social security
# ...                        ...                                           ...
# 37434  Uzbekistan, Republic of                         Social security funds
# 38901  Uzbekistan, Republic of                  Budgetary central government
# 38903  Uzbekistan, Republic of  Central government including social security
# 38960  Uzbekistan, Republic of                  Budgetary central government
# 38996  Uzbekistan, Republic of                              State Government
#
#                                                 GFS_GRP  \
# 18272  Transactions in financial assets and liabilities
# 18913                                   Balancing Items
# 19113                                           Revenue
# 19190                                       Expenditure
# 19276                                   Balancing Items
# ...                                                 ...
# 37434                                           Revenue
# 38901                                           Revenue
# 38903                                           Revenue
# 38960  Transactions in financial assets and liabilities
# 38996  Transactions in financial assets and liabilities
#
#                                                INDICATOR  \
# 18272  Domestic Creditors, Liabilities, Transactions ...
# 18913  Cash inflow from financing activities, Transac...
# 19113  Grants in cash receivable, Transactions (cash ...
# 19190  Interest payable, Transactions (cash basis of ...
# 19276  Primary net lending (+) / net borrowing (-), T...
# ...                                                  ...
# 37434  Grants in cash receivable, Transactions (cash ...
# 38901  Grants in cash receivable, Transactions (cash ...
# 38903  Taxes, Transactions (cash basis of recording),...
# 38960  Net acquisition of financial assets other than...
# 38996  Net acquisition of financial assets other than...
#
#       TYPE_OF_TRANSFORMATION FREQUENCY  1972  ...         2016        2017  \
# 18272      Domestic currency    Annual   NaN  ...    -4.670022  -11.525045
# 18913         Percent of GDP    Annual   NaN  ...    -1.167433   -3.226774
# 19113      Domestic currency    Annual   NaN  ...     0.000000   13.171974
# 19190      Domestic currency    Annual   NaN  ...    55.710718  107.870004
# 19276         Percent of GDP    Annual   NaN  ...     3.432921    0.961990
# ...                      ...       ...   ...  ...          ...         ...
# 37434         Percent of GDP    Annual   NaN  ...     0.008540    0.000000
# 38901         Percent of GDP    Annual   NaN  ...     0.040946    0.000000
# 38903         Percent of GDP    Annual   NaN  ...    13.432963   10.368747
# 38960      Domestic currency    Annual   NaN  ...  1345.920289  621.189642
# 38996      Domestic currency    Annual   NaN  ...     0.000000    0.000000
#
#               2018         2019         2020          2021          2022  \
# 18272   -21.283112   653.893399  2317.226533  -3851.143307  -3170.274425
# 18913    -3.480518    -2.887601    -1.161730      0.059743      0.536622
# 19113   289.688600    19.000000     0.000000  11134.843307  17394.704947
# 19190   259.413507  1042.717232  1731.387799   2286.537337   3477.819217
# 19276     1.702374     0.966643    -1.134420     -3.983062     -3.141319
# ...            ...          ...          ...           ...           ...
# 37434     0.031669     0.036996     1.423823      1.357020      1.156420
# 38901     0.000000     0.003195     0.172896      0.000000      0.590785
# 38903    12.695287    11.301967    13.402029     13.362903     11.988741
# 38960  4338.196364  4149.146377  1242.695130   1521.629862   1521.629862
# 38996     7.189625     1.000000     0.000000      0.000000      0.000000
#
#                2023  2024  2025
# 18272   5725.270689   NaN   NaN
# 18913      3.264229   NaN   NaN
# 19113   8776.045116   NaN   NaN
# 19190   8303.695853   NaN   NaN
# 19276     -3.622547   NaN   NaN
# ...             ...   ...   ...
# 37434      1.183962   NaN   NaN
# 38901      1.297131   NaN   NaN
# 38903     11.648873   NaN   NaN
# 38960  10297.122402   NaN   NaN
# 38996     47.402957   NaN   NaN
#
# [528 rows x 63 columns]

# %%
filtr = ds.INDICATOR.iloc[1]
ds = ds[ds.INDICATOR == filtr]
ds
# Out:
#                         DATASET                                SERIES_CODE  \
# 18913  IMF.STA:GFS_SSUC(10.0.0)       UZB.S1321.BI.GNFB_TCB_CAB.POGDP_PT.A
# 19830  IMF.STA:GFS_SSUC(10.0.0)            UZB.S1314.BI.GNFB_TCB_CAB.XDC.A
# 20291  IMF.STA:GFS_SSUC(10.0.0)      UZB.S13112.BI.GNFB_TCB_CAB.POGDP_PT.A
# 20698  IMF.STA:GFS_SSUC(10.0.0)       UZB.S1313MIXED.BI.GNFB_TCB_CAB.XDC.A
# 21561  IMF.STA:GFS_SSUC(10.0.0)      UZB.S1311B.BI.GNFB_TCB_CAB.POGDP_PT.A
# 21702  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1313MIXED.BI.GNFB_TCB_CAB.POGDP_PT.A
# 22049  IMF.STA:GFS_SSUC(10.0.0)              UZB.S13.BI.GNFB_TCB_CAB.XDC.A
# 22269  IMF.STA:GFS_SSUC(10.0.0)           UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A
# 22275  IMF.STA:GFS_SSUC(10.0.0)            UZB.S1311.BI.GNFB_TCB_CAB.XDC.A
# 22536  IMF.STA:GFS_SSUC(10.0.0)       UZB.S1311.BI.GNFB_TCB_CAB.POGDP_PT.A
# 22718  IMF.STA:GFS_SSUC(10.0.0)           UZB.S13112.BI.GNFB_TCB_CAB.XDC.A
# 22940  IMF.STA:GFS_SSUC(10.0.0)         UZB.S13.BI.GNFB_TCB_CAB.POGDP_PT.A
# 22948  IMF.STA:GFS_SSUC(10.0.0)       UZB.S1314.BI.GNFB_TCB_CAB.POGDP_PT.A
# 23194  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1312MIXED.BI.GNFB_TCB_CAB.POGDP_PT.A
# 24986  IMF.STA:GFS_SSUC(10.0.0)            UZB.S1321.BI.GNFB_TCB_CAB.XDC.A
# 25015  IMF.STA:GFS_SSUC(10.0.0)       UZB.S1312MIXED.BI.GNFB_TCB_CAB.XDC.A
#
#       OBS_MEASURE                  COUNTRY  \
# 18913   OBS_VALUE  Uzbekistan, Republic of
# 19830   OBS_VALUE  Uzbekistan, Republic of
# 20291   OBS_VALUE  Uzbekistan, Republic of
# 20698   OBS_VALUE  Uzbekistan, Republic of
# 21561   OBS_VALUE  Uzbekistan, Republic of
# 21702   OBS_VALUE  Uzbekistan, Republic of
# 22049   OBS_VALUE  Uzbekistan, Republic of
# 22269   OBS_VALUE  Uzbekistan, Republic of
# 22275   OBS_VALUE  Uzbekistan, Republic of
# 22536   OBS_VALUE  Uzbekistan, Republic of
# 22718   OBS_VALUE  Uzbekistan, Republic of
# 22940   OBS_VALUE  Uzbekistan, Republic of
# 22948   OBS_VALUE  Uzbekistan, Republic of
# 23194   OBS_VALUE  Uzbekistan, Republic of
# 24986   OBS_VALUE  Uzbekistan, Republic of
# 25015   OBS_VALUE  Uzbekistan, Republic of
#
#                                              SECTOR          GFS_GRP  \
# 18913  Central government including social security  Balancing Items
# 19830                         Social security funds  Balancing Items
# 20291             Extrabudgetary central government  Balancing Items
# 20698                              Local Government  Balancing Items
# 21561                  Budgetary central government  Balancing Items
# 21702                              Local Government  Balancing Items
# 22049                            General government  Balancing Items
# 22269                  Budgetary central government  Balancing Items
# 22275  Central government excluding social security  Balancing Items
# 22536  Central government excluding social security  Balancing Items
# 22718             Extrabudgetary central government  Balancing Items
# 22940                            General government  Balancing Items
# 22948                         Social security funds  Balancing Items
# 23194                              State Government  Balancing Items
# 24986  Central government including social security  Balancing Items
# 25015                              State Government  Balancing Items
#
#                                                INDICATOR  \
# 18913  Cash inflow from financing activities, Transac...
# 19830  Cash inflow from financing activities, Transac...
# 20291  Cash inflow from financing activities, Transac...
# 20698  Cash inflow from financing activities, Transac...
# 21561  Cash inflow from financing activities, Transac...
# 21702  Cash inflow from financing activities, Transac...
# 22049  Cash inflow from financing activities, Transac...
# 22269  Cash inflow from financing activities, Transac...
# 22275  Cash inflow from financing activities, Transac...
# 22536  Cash inflow from financing activities, Transac...
# 22718  Cash inflow from financing activities, Transac...
# 22940  Cash inflow from financing activities, Transac...
# 22948  Cash inflow from financing activities, Transac...
# 23194  Cash inflow from financing activities, Transac...
# 24986  Cash inflow from financing activities, Transac...
# 25015  Cash inflow from financing activities, Transac...
#
#       TYPE_OF_TRANSFORMATION FREQUENCY  1972  ...         2016          2017  \
# 18913         Percent of GDP    Annual   NaN  ...    -1.167433     -3.226774
# 19830      Domestic currency    Annual   NaN  ...     0.000000      0.000000
# 20291         Percent of GDP    Annual   NaN  ...    -0.553810     -2.939377
# 20698      Domestic currency    Annual   NaN  ...          NaN           NaN
# 21561         Percent of GDP    Annual   NaN  ...    -0.613624     -0.287398
# 21702         Percent of GDP    Annual   NaN  ...          NaN           NaN
# 22049      Domestic currency    Annual   NaN  ... -2962.364849 -11543.836191
# 22269      Domestic currency    Annual   NaN  ... -1567.328826  -1024.439772
# 22275      Domestic currency    Annual   NaN  ... -2981.879597 -11501.960852
# 22536         Percent of GDP    Annual   NaN  ...    -1.167433     -3.226774
# 22718      Domestic currency    Annual   NaN  ... -1414.550771 -10477.521080
# 22940         Percent of GDP    Annual   NaN  ...    -1.159793     -3.238522
# 22948         Percent of GDP    Annual   NaN  ...     0.000000      0.000000
# 23194         Percent of GDP    Annual   NaN  ...     0.007640     -0.011748
# 24986      Domestic currency    Annual   NaN  ... -2981.879597 -11501.960852
# 25015      Domestic currency    Annual   NaN  ...    19.514749    -41.875339
#
#                2018          2019         2020         2021         2022  \
# 18913     -3.480518     -2.887601    -1.161730     0.059743     0.536622
# 19830    -15.745900    -19.289518     0.000000   -15.000000    15.000000
# 20291     -2.403271     -2.036677    -0.976066     1.023711     0.395342
# 20698           NaN           NaN          NaN          NaN          NaN
# 21561     -1.073922     -0.847681    -0.185665    -0.962140     0.139774
# 21702           NaN           NaN          NaN          NaN          NaN
# 22049 -16593.867187 -17281.766852 -7904.782354  -224.422609  3871.668042
# 22269  -5086.664175  -5040.813509 -1240.309321 -7894.710054  1391.553583
# 22275 -16469.827643 -17152.103602 -7760.798014   505.217175  5327.467210
# 22536     -3.477194     -2.884357    -1.161730     0.061572     0.535116
# 22718 -11383.163468 -12111.290093 -6520.488694  8399.927229  3935.913627
# 22940     -3.503381     -2.906162    -1.183284    -0.027351     0.388888
# 22948     -0.003324     -0.003244     0.000000    -0.001828     0.001507
# 23194     -0.022864     -0.018561    -0.021553    -0.087094    -0.147734
# 24986 -16485.573543 -17171.393120 -7760.798014   490.217175  5342.467210
# 25015   -108.293644   -110.373732  -143.984339  -714.639784 -1470.799168
#
#                2023  2024  2025
# 18913      3.264229   NaN   NaN
# 19830      0.748766   NaN   NaN
# 20291     -2.085866   NaN   NaN
# 20698           NaN   NaN   NaN
# 21561      5.350095   NaN   NaN
# 21702           NaN   NaN   NaN
# 22049  38452.420433   NaN   NaN
# 22269  63781.828860   NaN   NaN
# 22275  38914.916897   NaN   NaN
# 22536      3.264229   NaN   NaN
# 22718 -24866.911963   NaN   NaN
# 22940      3.225434   NaN   NaN
# 22948      0.000063   NaN   NaN
# 23194     -0.038858   NaN   NaN
# 24986  38914.917175   NaN   NaN
# 25015   -463.245230   NaN   NaN
#
# [16 rows x 63 columns]

# %%
dset = pd.read_csv("dataset2.csv")
dset
# Out:
#                     DATASET                       SERIES_CODE OBS_MEASURE  \
# 0  IMF.STA:GFS_SSUC(10.0.0)   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE
# 1  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE
# 2  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE
# 3  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE
# 4  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE
#
#       SCALE  2005  2006  2007  2008  2009  2010  ...         2014  \
# 0  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...   922.914964
# 1  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...  -157.998668
# 2  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...  1978.827977
# 3  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ... -1039.065949
# 4  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...   881.067254
#
#           2015         2016         2017         2018          2019  \
# 0   316.137150  1052.269527   805.085301  3424.157818  -1172.599584
# 1  -792.876325  -570.200251  -327.224475 -1921.919864  -7256.130325
# 2  1599.849034  2554.884076  2884.107083  7289.667377  13158.021544
# 3 -1067.592274 -1567.328826 -1024.439772 -5086.664175  -5040.813509
# 4   274.715957   997.128623   697.215298  3164.744311  -2215.316816
#
#            2020          2021          2022          2023
# 0  -8626.643172 -26816.096377 -27997.116972 -45497.747129
# 1 -11598.340291 -36979.621313 -30083.382606   9992.773667
# 2   3033.441266 -12336.514210  -5931.890767 -35230.713535
# 3  -1240.309321  -7894.710054   1391.553583  63781.828860
# 4 -10358.030971 -29084.911259 -31474.936189 -53789.055467
#
# [5 rows x 23 columns]

# %%
dset.drop(['DATASET'],axis=1,inplace=True)
dset
# Out:
#                         SERIES_CODE OBS_MEASURE     SCALE  2005  2006  2007  \
# 0   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE  Billions   NaN   NaN   NaN
# 1  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE  Billions   NaN   NaN   NaN
# 2  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE  Billions   NaN   NaN   NaN
# 3  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE  Billions   NaN   NaN   NaN
# 4  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE  Billions   NaN   NaN   NaN
#
#    2008  2009  2010       2011  ...         2014         2015         2016  \
# 0   NaN   NaN   NaN   535.8980  ...   922.914964   316.137150  1052.269527
# 1   NaN   NaN   NaN   175.4004  ...  -157.998668  -792.876325  -570.200251
# 2   NaN   NaN   NaN  1159.7338  ...  1978.827977  1599.849034  2554.884076
# 3   NaN   NaN   NaN  -326.5946  ... -1039.065949 -1067.592274 -1567.328826
# 4   NaN   NaN   NaN   501.9949  ...   881.067254   274.715957   997.128623
#
#           2017         2018          2019          2020          2021  \
# 0   805.085301  3424.157818  -1172.599584  -8626.643172 -26816.096377
# 1  -327.224475 -1921.919864  -7256.130325 -11598.340291 -36979.621313
# 2  2884.107083  7289.667377  13158.021544   3033.441266 -12336.514210
# 3 -1024.439772 -5086.664175  -5040.813509  -1240.309321  -7894.710054
# 4   697.215298  3164.744311  -2215.316816 -10358.030971 -29084.911259
#
#            2022          2023
# 0 -27997.116972 -45497.747129
# 1 -30083.382606   9992.773667
# 2  -5931.890767 -35230.713535
# 3   1391.553583  63781.828860
# 4 -31474.936189 -53789.055467
#
# [5 rows x 22 columns]

# %%
dset.drop(['SCALE'],axis=1,inplace=True)
dset
# Out:
#                         SERIES_CODE OBS_MEASURE  2005  2006  2007  2008  2009  \
# 0   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE   NaN   NaN   NaN   NaN   NaN
# 1  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE   NaN   NaN   NaN   NaN   NaN
# 2  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE   NaN   NaN   NaN   NaN   NaN
# 3  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE   NaN   NaN   NaN   NaN   NaN
# 4  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE   NaN   NaN   NaN   NaN   NaN
#
#    2010       2011         2012  ...         2014         2015         2016  \
# 0   NaN   535.8980  1098.939514  ...   922.914964   316.137150  1052.269527
# 1   NaN   175.4004   815.210000  ...  -157.998668  -792.876325  -570.200251
# 2   NaN  1159.7338  1772.831714  ...  1978.827977  1599.849034  2554.884076
# 3   NaN  -326.5946  -247.494300  ... -1039.065949 -1067.592274 -1567.328826
# 4   NaN   501.9949  1062.704214  ...   881.067254   274.715957   997.128623
#
#           2017         2018          2019          2020          2021  \
# 0   805.085301  3424.157818  -1172.599584  -8626.643172 -26816.096377
# 1  -327.224475 -1921.919864  -7256.130325 -11598.340291 -36979.621313
# 2  2884.107083  7289.667377  13158.021544   3033.441266 -12336.514210
# 3 -1024.439772 -5086.664175  -5040.813509  -1240.309321  -7894.710054
# 4   697.215298  3164.744311  -2215.316816 -10358.030971 -29084.911259
#
#            2022          2023
# 0 -27997.116972 -45497.747129
# 1 -30083.382606   9992.773667
# 2  -5931.890767 -35230.713535
# 3   1391.553583  63781.828860
# 4 -31474.936189 -53789.055467
#
# [5 rows x 21 columns]

# %%
cols = [str(y) for y in range(2005, 2010)]
dset.drop(columns=cols,inplace=True)
dset
# Out:
#                         SERIES_CODE OBS_MEASURE  2010       2011         2012  \
# 0   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE   NaN   535.8980  1098.939514
# 1  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE   NaN   175.4004   815.210000
# 2  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE   NaN  1159.7338  1772.831714
# 3  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE   NaN  -326.5946  -247.494300
# 4  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE   NaN   501.9949  1062.704214
#
#           2013         2014         2015         2016         2017  \
# 0   658.224577   922.914964   316.137150  1052.269527   805.085301
# 1     4.833142  -157.998668  -792.876325  -570.200251  -327.224475
# 2  1440.100000  1978.827977  1599.849034  2554.884076  2884.107083
# 3  -620.055858 -1039.065949 -1067.592274 -1567.328826 -1024.439772
# 4   624.932000   881.067254   274.715957   997.128623   697.215298
#
#           2018          2019          2020          2021          2022  \
# 0  3424.157818  -1172.599584  -8626.643172 -26816.096377 -27997.116972
# 1 -1921.919864  -7256.130325 -11598.340291 -36979.621313 -30083.382606
# 2  7289.667377  13158.021544   3033.441266 -12336.514210  -5931.890767
# 3 -5086.664175  -5040.813509  -1240.309321  -7894.710054   1391.553583
# 4  3164.744311  -2215.316816 -10358.030971 -29084.911259 -31474.936189
#
#            2023
# 0 -45497.747129
# 1   9992.773667
# 2 -35230.713535
# 3  63781.828860
# 4 -53789.055467

# %%
dset
# Out:
#                         SERIES_CODE OBS_MEASURE  2010       2011         2012  \
# 0   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE   NaN   535.8980  1098.939514
# 1  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE   NaN   175.4004   815.210000
# 2  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE   NaN  1159.7338  1772.831714
# 3  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE   NaN  -326.5946  -247.494300
# 4  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE   NaN   501.9949  1062.704214
#
#           2013         2014         2015         2016         2017  \
# 0   658.224577   922.914964   316.137150  1052.269527   805.085301
# 1     4.833142  -157.998668  -792.876325  -570.200251  -327.224475
# 2  1440.100000  1978.827977  1599.849034  2554.884076  2884.107083
# 3  -620.055858 -1039.065949 -1067.592274 -1567.328826 -1024.439772
# 4   624.932000   881.067254   274.715957   997.128623   697.215298
#
#           2018          2019          2020          2021          2022  \
# 0  3424.157818  -1172.599584  -8626.643172 -26816.096377 -27997.116972
# 1 -1921.919864  -7256.130325 -11598.340291 -36979.621313 -30083.382606
# 2  7289.667377  13158.021544   3033.441266 -12336.514210  -5931.890767
# 3 -5086.664175  -5040.813509  -1240.309321  -7894.710054   1391.553583
# 4  3164.744311  -2215.316816 -10358.030971 -29084.911259 -31474.936189
#
#            2023
# 0 -45497.747129
# 1   9992.773667
# 2 -35230.713535
# 3  63781.828860
# 4 -53789.055467

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset2.csv')
df
# Out:
#                     DATASET                       SERIES_CODE OBS_MEASURE  \
# 0  IMF.STA:GFS_SSUC(10.0.0)   UZB.S1311B.BI.GPB_TCB_CAB.XDC.A   OBS_VALUE
# 1  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.NCSC_TCB_CAB.XDC.A   OBS_VALUE
# 2  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.CIOA_TCB_CAB.XDC.A   OBS_VALUE
# 3  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.GNFB_TCB_CAB.XDC.A   OBS_VALUE
# 4  IMF.STA:GFS_SSUC(10.0.0)  UZB.S1311B.BI.GNLB_TCB_CAB.XDC.A   OBS_VALUE
#
#       SCALE  2005  2006  2007  2008  2009  2010  ...         2014  \
# 0  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...   922.914964
# 1  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...  -157.998668
# 2  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...  1978.827977
# 3  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ... -1039.065949
# 4  Billions   NaN   NaN   NaN   NaN   NaN   NaN  ...   881.067254
#
#           2015         2016         2017         2018          2019  \
# 0   316.137150  1052.269527   805.085301  3424.157818  -1172.599584
# 1  -792.876325  -570.200251  -327.224475 -1921.919864  -7256.130325
# 2  1599.849034  2554.884076  2884.107083  7289.667377  13158.021544
# 3 -1067.592274 -1567.328826 -1024.439772 -5086.664175  -5040.813509
# 4   274.715957   997.128623   697.215298  3164.744311  -2215.316816
#
#            2020          2021          2022          2023
# 0  -8626.643172 -26816.096377 -27997.116972 -45497.747129
# 1 -11598.340291 -36979.621313 -30083.382606   9992.773667
# 2   3033.441266 -12336.514210  -5931.890767 -35230.713535
# 3  -1240.309321  -7894.710054   1391.553583  63781.828860
# 4 -10358.030971 -29084.911259 -31474.936189 -53789.055467
#
# [5 rows x 23 columns]
