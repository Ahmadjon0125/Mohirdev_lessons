# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
obj = Series([4,5,6,-6.5])
type(obj)
# Out:
# pandas.Series

# %%
obj
# Out:
# 0    4.0
# 1    5.0
# 2    6.0
# 3   -6.5
# dtype: float64

# %%
obj.values
# Out:
# array([ 4. ,  5. ,  6. , -6.5])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj[0]
# Out:
# np.float64(4.0)

# %%
obj2 = Series([6,3,2,1], index=["a","b","c","d"])
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
obj2["a"]
# Out:
# np.int64(6)

# %%
obj2[["a","d"]]
# Out:
# a    6
# d    1
# dtype: int64

# %%
obj2[obj2> 2]
# Out:
# a    6
# b    3
# dtype: int64

# %%
np.exp(obj2) # e darajasi x bo'yicha hisoblar ekan
# Out:
# a    403.428793
# b     20.085537
# c      7.389056
# d      2.718282
# dtype: float64

# %%
obj2["a"]
# Out:
# np.int64(6)

# %%
obj2
# Out:
# a    6
# b    3
# c    2
# d    1
# dtype: int64

# %%
cars_dict = {
    'Malibu': 40000, 
    'Lacetti': 20000, 
    'Toyota': 45000, 
    'Mazda': 52000, 
    'Honda': 38000
}

type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict)
type(cars1)
# Out:
# pandas.Series

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars1 = Series({
    'Malibu': 40000, 
    'Lacetti': 20000, 
    'Toyota': 45000, 
    'Mazda': 52000, 
    'Honda': 38000
})
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
"Malibu" in cars1
# Out:
# True

# %%
"BMW" in cars1
# Out:
# False

# %%
cars1["Toyota"]
# Out:
# np.int64(45000)

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
models = ['Honda', 'Mazda', 'Lacetti', 'Jaguar', 'Malibu', 'Damas', 'Toyota']
cars2 = Series(cars_dict, index=models )
cars2
# Out:
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jaguar         NaN
# Malibu     40000.0
# Damas          NaN
# Toyota     45000.0
# dtype: float64

# %%
cars2.isnull()
# Out:
# Honda      False
# Mazda      False
# Lacetti    False
# Jaguar      True
# Malibu     False
# Damas       True
# Toyota     False
# dtype: bool

# %%
cars2.notnull()
# Out:
# Honda       True
# Mazda       True
# Lacetti     True
# Jaguar     False
# Malibu      True
# Damas      False
# Toyota      True
# dtype: bool

# %%
cars2
# Out:
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jaguar         NaN
# Malibu     40000.0
# Damas          NaN
# Toyota     45000.0
# dtype: float64

# %%
cars1
# Out:
# Malibu     40000
# Lacetti    20000
# Toyota     45000
# Mazda      52000
# Honda      38000
# dtype: int64

# %%
cars1+cars2
# Out:
# Damas           NaN
# Honda       76000.0
# Jaguar          NaN
# Lacetti     40000.0
# Malibu      80000.0
# Mazda      104000.0
# Toyota      90000.0
# dtype: float64

# %%
cars2.name = "Avtosalon"
cars2.index.name = "Modellar"

# %%
cars2
# Out:
# Modellar
# Honda      38000.0
# Mazda      52000.0
# Lacetti    20000.0
# Jaguar         NaN
# Malibu     40000.0
# Damas          NaN
# Toyota     45000.0
# Name: Avtosalon, dtype: float64
