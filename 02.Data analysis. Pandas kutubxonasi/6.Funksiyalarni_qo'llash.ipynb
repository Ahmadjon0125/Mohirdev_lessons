# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -1.213396  0.331102 -0.129994 -0.147908
# b  1.469557 -1.397087  1.184603  0.634715
# c  1.319551 -0.927369  0.140952 -0.660071

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.213396  0.331102  0.129994  0.147908
# b  1.469557  1.397087  1.184603  0.634715
# c  1.319551  0.927369  0.140952  0.660071

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0   0.0   -0.0   -0.0
# b   1.0  -1.0    1.0    1.0
# c   1.0  -1.0    0.0   -1.0

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -1.213396  0.331102 -0.129994 -0.147908
# b  1.469557 -1.397087  1.184603  0.634715
# c  1.319551 -0.927369  0.140952 -0.660071

# %%
df.mean()
# Out:
# Olma     0.525237
# Anor    -0.664451
# Qovun    0.398520
# Anjir   -0.057755
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a   -0.290049
# b    0.472947
# c   -0.031734
# dtype: float64

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  1.213396  0.331102  0.129994  0.147908
# b  1.469557  1.397087  1.184603  0.634715
# c  1.319551  0.927369  0.140952  0.660071

# %%
df.apply(sum)
# Out:
# Olma     1.575712
# Anor    -1.993354
# Qovun    1.195561
# Anjir   -0.173264
# dtype: float64

# %%
df.apply(sum, axis=1)
# Out:
# a   -1.160196
# b    1.891789
# c   -0.126938
# dtype: float64

# %%
f = lambda x : x.max() - x.min()

# %%
df.apply(f)
# Out:
# Olma     2.682954
# Anor     1.728189
# Qovun    1.314597
# Anjir    1.294786
# dtype: float64

# %%
def foo(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -1.213396 -1.397087 -0.129994 -0.660071
# max  1.469557  0.331102  1.184603  0.634715

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     2      3      4
# b     5     6      7      8
# c     9    10     11     12

# %%
df.applymap(lambda x: x*x)#bu eskiribdi o'rniga shunchaki map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_24516/3316139181.py in ?()
# ----> 1 df.applymap(lambda x: x*x)
#
# ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'applymap'

# %%
df.map(lambda x: x*x)
# Out:
#    Olma  Anor  Qovun  Anjir
# a     1     4      9     16
# b    25    36     49     64
# c    81   100    121    144
