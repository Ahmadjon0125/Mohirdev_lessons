# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Yil': [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010],
    'Aholi soni': [33.9, 33.5, 32.9, 32.5, 31.9, 31.4, 30.9, 28.5],
    'Temp': [1.54, 1.48, 1.56, 1.62, 1.65, 1.66, 1.64, 1.53],
    'Zichlik': [79.77, 78.68, 77.53, 76.34, 75.13, 73.91, 72.71, 67.03]
}

df = pd.DataFrame(data)
df
# Out:
#     Yil  Aholi soni  Temp  Zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.48    78.68
# 2  2019        32.9  1.56    77.53
# 3  2018        32.5  1.62    76.34
# 4  2017        31.9  1.65    75.13
# 5  2016        31.4  1.66    73.91
# 6  2015        30.9  1.64    72.71
# 7  2010        28.5  1.53    67.03

# %%
data= df["Aholi soni"]
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
data= df[["Aholi soni"]]
data
# Out:
#    Aholi soni
# 0        33.9
# 1        33.5
# 2        32.9
# 3        32.5
# 4        31.9
# 5        31.4
# 6        30.9
# 7        28.5

# %%
data= df["Aholi soni"]
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
type(data[0])
# Out:
# numpy.float64

# %%
type(data[[0]])
# Out:
# pandas.Series

# %%
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.4
# 6    30.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
data[0:4]
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# Name: Aholi soni, dtype: float64

# %%
data[[2,4,7]]
# Out:
# 2    32.9
# 4    31.9
# 7    28.5
# Name: Aholi soni, dtype: float64

# %%
obj = pd.Series(np.arange(8), index = ['a', 'b', 'c', 'd','e','f','g','h'])
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj['a']  #qiymat ko'rinishida
# Out:
# np.int64(0)

# %%
obj[['a']]  #ro'yxat ya'ni series ko'rinishida
# Out:
# a    0
# dtype: int64

# %%
obj[0:4]
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj['a': 'f'] #lekin bunda f qiymat ham kiradi
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# dtype: int64

# %%
obj['c': 'h']
# Out:
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj[[1,5]] # bu usul ishlamadi
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 obj[[1,5]]
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/series.py:991, in Series.__getitem__(self, key)
#     988     key = np.asarray(key, dtype=bool)
#     989     return self._get_rows_with_mask(key)
# --> 991 return self._get_with(key)
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/series.py:1003, in Series._get_with(self, key)
#    1000 elif isinstance(key, tuple):
#    1001     return self._get_values_tuple(key)
# -> 1003 return self.loc[key]
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~/Desktop/Mohirdev/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([1, 5], dtype='int64')] are in the [index]"

# %%
obj.iloc[[1,5]]  # bu yangicha usul ekan
# Out:
# b    1
# f    5
# dtype: int64

# %%
obj[['a', 'g']]
# Out:
# a    0
# g    6
# dtype: int64

# %%
obj['a':'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
obj['a':'c']=10

# %%
obj
# Out:
# a    10
# b    10
# c    10
# d     3
# e     4
# f     5
# g     6
# h     7
# dtype: int64

# %%
obj[obj<10]
# Out:
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %% [markdown]
# ### Elementlarni tanlash , DataFrame

# %%
uz = {2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9, 2016:31.4, 2015:30.9}
kz = {2020:18.8, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8, 2015:17.6}
tj = {2020:9.5, 2019:9.3, 2018:9.1, 2017:8.9, 2016:8.7, 2015:8.5}
kg = {2020:6.5, 2019:6.4, 2018:6.3, 2017:6.2, 2016:6.1, 2015:6.0}
tr = {2020:6.0, 2019:5.9, 2018:5.9, 2017:5.8, 2016:5.6, 2015:5.6}

df = pd.DataFrame({
    'Uzbekistan': uz,
    'Kazakhstan': kz,
    'Tajikistan': tj,
    'Kyrgyzstan': kg,
    'Turkmenistan': tr
})

print(df)
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.9
# 2018        32.5        18.3         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df['Uzbekistan']
# Out:
# 2020    33.5
# 2019    32.9
# 2018    32.5
# 2017    31.9
# 2016    31.4
# 2015    30.9
# Name: Uzbekistan, dtype: float64

# %%
df[['Uzbekistan']]
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5
# 2017        31.9
# 2016        31.4
# 2015        30.9

# %%
df['Uzbekistan'].to_numpy()
# Out:
# array([33.5, 32.9, 32.5, 31.9, 31.4, 30.9])

# %%
df[['Uzbekistan','Turkmenistan']]
# Out:
#       Uzbekistan  Turkmenistan
# 2020        33.5           6.0
# 2019        32.9           5.9
# 2018        32.5           5.9
# 2017        31.9           5.8
# 2016        31.4           5.6
# 2015        30.9           5.6

# %%
df[3:]
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.9
# 2018        32.5        18.3         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df>10
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        True        True       False       False         False
# 2019        True        True       False       False         False
# 2018        True        True       False       False         False
# 2017        True        True       False       False         False
# 2016        True        True       False       False         False
# 2015        True        True       False       False         False

# %%
df[['Uzbekistan']][df['Uzbekistan'] >32]
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5

# %%
dfuz = df[['Uzbekistan']]
dfuz
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5
# 2017        31.9
# 2016        31.4
# 2015        30.9

# %%
dfuz[dfuz['Uzbekistan']>32]
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5

# %%
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.9
# 2018        32.5        18.3         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df2 = df.transpose().copy()
df2
# Out:
#               2020  2019  2018  2017  2016  2015
# Uzbekistan    33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhstan    18.8  18.5  18.3  18.1  17.8  17.6
# Tajikistan     9.5   9.3   9.1   8.9   8.7   8.5
# Kyrgyzstan     6.5   6.4   6.3   6.2   6.1   6.0
# Turkmenistan   6.0   5.9   5.9   5.8   5.6   5.6

# %%
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.9
# 2018        32.5        18.3         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df2
# Out:
#               2020  2019  2018  2017  2016  2015
# Uzbekistan    33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhstan    18.8  18.5  18.3  18.1  17.8  17.6
# Tajikistan     9.5   9.3   9.1   8.9   8.7   8.5
# Kyrgyzstan     6.5   6.4   6.3   6.2   6.1   6.0
# Turkmenistan   6.0   5.9   5.9   5.8   5.6   5.6

# %%
df2[df2[2015]>6]
# Out:
#             2020  2019  2018  2017  2016  2015
# Uzbekistan  33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhstan  18.8  18.5  18.3  18.1  17.8  17.6
# Tajikistan   9.5   9.3   9.1   8.9   8.7   8.5

# %% [markdown]
# ### .loc va .iloc

# %%
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.5         9.3         6.4           5.9
# 2018        32.5        18.3         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df[['Kazakhstan']]
# Out:
#       Kazakhstan
# 2020        18.8
# 2019        18.5
# 2018        18.3
# 2017        18.1
# 2016        17.8
# 2015        17.6

# %%
df.loc[[2017]]
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2017        31.9        18.1         8.9         6.2           5.8

# %%
df.loc[2017]
# Out:
# Uzbekistan      31.9
# Kazakhstan      18.1
# Tajikistan       8.9
# Kyrgyzstan       6.2
# Turkmenistan     5.8
# Name: 2017, dtype: float64

# %%
df.loc[[2015, 2017],["Uzbekistan", "Tajikistan"]]
# Out:
#       Uzbekistan  Tajikistan
# 2015        30.9         8.5
# 2017        31.9         8.9

# %%
df.iloc[[0,4]]
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2016        31.4        17.8         8.7         6.1           5.6

# %%
df.iloc[[0,4],[0,4,3]]
# Out:
#       Uzbekistan  Turkmenistan  Kyrgyzstan
# 2020        33.5           6.0         6.5
# 2016        31.4           5.6         6.1

# %%
df.at[2015, "Uzbekistan"]
# Out:
# np.float64(30.9)

# %%
df.iat[2,4]
# Out:
# np.float64(5.9)
